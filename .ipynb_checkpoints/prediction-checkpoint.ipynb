# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold


train_rd = pd.read_csv('train.csv')
test_rd = pd.read_csv('test.csv')

group_0 = train_rd.loc[train_rd['target']==0]
group_1 = train_rd.loc[train_rd['target']==1]

# %%
features = [c for c in train_rd.columns if c not in ['ID_code', 'target']]
target = train_rd['target']

param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.333,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.01,
    'max_depth': -1,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 10,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': 1
}

# %%
folds = StratifiedKFold(n_splits=15, shuffle=False,random_state=2319)
predictions = np.zeros(len(test_rd))

predictions_list = []

for fold_count, (train_idx, valid_idx) in enumerate(folds.split(train_rd.values, target.values)):
    
    train_data = lgb.Dataset(train_rd.iloc[train_idx][features],label=target.iloc[train_idx])
    valid_data = lgb.Dataset(train_rd.iloc[valid_idx][features],label=target.iloc[valid_idx])
    
    clf = lgb.train(param, train_data, 50000, valid_sets = valid_data, verbose_eval=1000, early_stopping_rounds = 2000)
    
    predictions = clf.predict(test_rd[features], num_iteration=clf.best_iteration)
    
    print('\n============== Prediction iteration END ==============\n')
    
    predictions_list.append(predictions)
# Out:
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.885016
# [2000]	valid_0's auc: 0.892227
# [3000]	valid_0's auc: 0.896475
# [4000]	valid_0's auc: 0.899065
# [5000]	valid_0's auc: 0.900447
# [6000]	valid_0's auc: 0.901571
# [7000]	valid_0's auc: 0.901676
# [8000]	valid_0's auc: 0.901954
# [9000]	valid_0's auc: 0.901888
# [10000]	valid_0's auc: 0.90228
# [11000]	valid_0's auc: 0.902158
# [12000]	valid_0's auc: 0.90199
# Early stopping, best iteration is:
# [10249]	valid_0's auc: 0.902314
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.880161
# [2000]	valid_0's auc: 0.88703
# [3000]	valid_0's auc: 0.890401
# [4000]	valid_0's auc: 0.892029
# [5000]	valid_0's auc: 0.893111
# [6000]	valid_0's auc: 0.893598
# [7000]	valid_0's auc: 0.893823
# [8000]	valid_0's auc: 0.893706
# [9000]	valid_0's auc: 0.89376
# Early stopping, best iteration is:
# [7427]	valid_0's auc: 0.894004
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.887649
# [2000]	valid_0's auc: 0.896118
# [3000]	valid_0's auc: 0.899669
# [4000]	valid_0's auc: 0.901376
# [5000]	valid_0's auc: 0.90265
# [6000]	valid_0's auc: 0.903088
# [7000]	valid_0's auc: 0.903457
# [8000]	valid_0's auc: 0.903782
# [9000]	valid_0's auc: 0.903472
# [10000]	valid_0's auc: 0.903044
# Early stopping, best iteration is:
# [8115]	valid_0's auc: 0.903825
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.872252
# [2000]	valid_0's auc: 0.880194
# [3000]	valid_0's auc: 0.884063
# [4000]	valid_0's auc: 0.886505
# [5000]	valid_0's auc: 0.887725
# [6000]	valid_0's auc: 0.888563
# [7000]	valid_0's auc: 0.889104
# [8000]	valid_0's auc: 0.889571
# [9000]	valid_0's auc: 0.88954
# [10000]	valid_0's auc: 0.889917
# [11000]	valid_0's auc: 0.889922
# Early stopping, best iteration is:
# [9819]	valid_0's auc: 0.890024
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.892293
# [2000]	valid_0's auc: 0.901262
# [3000]	valid_0's auc: 0.905047
# [4000]	valid_0's auc: 0.906855
# [5000]	valid_0's auc: 0.908001
# [6000]	valid_0's auc: 0.908514
# [7000]	valid_0's auc: 0.908673
# [8000]	valid_0's auc: 0.908638
# Early stopping, best iteration is:
# [6471]	valid_0's auc: 0.908852
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.877346
# [2000]	valid_0's auc: 0.886234
# [3000]	valid_0's auc: 0.888955
# [4000]	valid_0's auc: 0.890654
# [5000]	valid_0's auc: 0.891761
# [6000]	valid_0's auc: 0.892079
# [7000]	valid_0's auc: 0.892538
# [8000]	valid_0's auc: 0.892547
# [9000]	valid_0's auc: 0.892422
# Early stopping, best iteration is:
# [7693]	valid_0's auc: 0.892663
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.883696
# [2000]	valid_0's auc: 0.892126
# [3000]	valid_0's auc: 0.896407
# [4000]	valid_0's auc: 0.897927
# [5000]	valid_0's auc: 0.898587
# [6000]	valid_0's auc: 0.899113
# [7000]	valid_0's auc: 0.899313
# [8000]	valid_0's auc: 0.899235
# Early stopping, best iteration is:
# [6610]	valid_0's auc: 0.899498
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.885618
# [2000]	valid_0's auc: 0.89345
# [3000]	valid_0's auc: 0.897157
# [4000]	valid_0's auc: 0.898554
# [5000]	valid_0's auc: 0.899396
# [6000]	valid_0's auc: 0.900121
# [7000]	valid_0's auc: 0.900345
# [8000]	valid_0's auc: 0.900506
# [9000]	valid_0's auc: 0.900624
# [10000]	valid_0's auc: 0.900365
# [11000]	valid_0's auc: 0.900344
# Early stopping, best iteration is:
# [9189]	valid_0's auc: 0.900704
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.890499
# [2000]	valid_0's auc: 0.898313
# [3000]	valid_0's auc: 0.901549
# [4000]	valid_0's auc: 0.903282
# [5000]	valid_0's auc: 0.904349
# [6000]	valid_0's auc: 0.904892
# [7000]	valid_0's auc: 0.905086
# [8000]	valid_0's auc: 0.904975
# Early stopping, best iteration is:
# [6810]	valid_0's auc: 0.905202
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2000 rounds.
# [1000]	valid_0's auc: 0.88898
# [2000]	valid_0's auc: 0.895712

# %%
result = pd.DataFrame({"ID_code":test_rd["ID_code"].values})

result['target'] = predictions_list['?']

result.to_csv("submission.csv", index=False)
