# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold


train_rd = pd.read_csv('train.csv')
test_rd = pd.read_csv('test.csv')

group_0 = train_rd.loc[train_rd['target']==0]
group_1 = train_rd.loc[train_rd['target']==1]

# %%
features = [c for c in train_rd.columns if c not in ['ID_code', 'target']]
target = train_rd['target']

param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.333,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.008,
    'max_depth': -1,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': 1
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e38307580a2> in <module>
# ----> 1 features = [c for c in train_rd.columns if c not in ['ID_code', 'target']]
#       2 target = train_rd['target']
#       3
#       4 param = {
#       5     'bagging_freq': 5,
#
# NameError: name 'train_rd' is not defined

# %%
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        
        # shuffle each cols(var) order
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
folds = StratifiedKFold(n_splits=15, shuffle=True,random_state=42)
predictions = np.zeros(len(test_rd))



for fold_count, (train_idx, valid_idx) in enumerate(folds.split(train_rd.values, target.values)):
    
    train_X,train_y = train_rd.iloc[train_idx][features] , target.iloc[train_idx]
    valid_X,valid_Y = train_rd.iloc[valid_idx][features] , target.iloc[valid_idx]
    
    N = 5
    
    
    for i in range(N):
        
        double_X,double_Y = augment(train_X.values,train_y.values)
        
    
        train_data = lgb.Dataset(double_X,label=double_Y)
        valid_data = lgb.Dataset(valid_X,label=valid_Y)

        clf = lgb.train(param, train_data, 50000, valid_sets = valid_data, verbose_eval=1000, early_stopping_rounds = 2500)

        predictions += clf.predict(test_rd[features], num_iteration=clf.best_iteration)/(folds.n_splits*N)
    
    
    print('\nfold %d completed\n' % fold_count)
# Out:
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.880148
# [2000]	valid_0's auc: 0.887472
# [3000]	valid_0's auc: 0.891998
# [4000]	valid_0's auc: 0.894494
# [5000]	valid_0's auc: 0.89648
# [6000]	valid_0's auc: 0.897876
# [7000]	valid_0's auc: 0.898763
# [8000]	valid_0's auc: 0.899367
# [9000]	valid_0's auc: 0.899661
# [10000]	valid_0's auc: 0.899949
# [11000]	valid_0's auc: 0.899957
# [12000]	valid_0's auc: 0.900053
# [13000]	valid_0's auc: 0.900094
# [14000]	valid_0's auc: 0.90002
# [15000]	valid_0's auc: 0.899937
# Early stopping, best iteration is:
# [12517]	valid_0's auc: 0.900114
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.880029
# [2000]	valid_0's auc: 0.88769
# [3000]	valid_0's auc: 0.891973
# [4000]	valid_0's auc: 0.894625
# [5000]	valid_0's auc: 0.89682
# [6000]	valid_0's auc: 0.898158
# [7000]	valid_0's auc: 0.899027
# [8000]	valid_0's auc: 0.899567
# [9000]	valid_0's auc: 0.899942
# [10000]	valid_0's auc: 0.900371
# [11000]	valid_0's auc: 0.900372
# [12000]	valid_0's auc: 0.900501
# [13000]	valid_0's auc: 0.900479
# [14000]	valid_0's auc: 0.900485
# Early stopping, best iteration is:
# [12110]	valid_0's auc: 0.900533
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.879302
# [2000]	valid_0's auc: 0.887009
# [3000]	valid_0's auc: 0.891421
# [4000]	valid_0's auc: 0.894418
# [5000]	valid_0's auc: 0.896604
# [6000]	valid_0's auc: 0.898018
# [7000]	valid_0's auc: 0.89894
# [8000]	valid_0's auc: 0.899441
# [9000]	valid_0's auc: 0.899797
# [10000]	valid_0's auc: 0.899976
# [11000]	valid_0's auc: 0.900095
# [12000]	valid_0's auc: 0.900194
# [13000]	valid_0's auc: 0.900168
# [14000]	valid_0's auc: 0.900174
# Early stopping, best iteration is:
# [12267]	valid_0's auc: 0.900208
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.879801
# [2000]	valid_0's auc: 0.887503
# [3000]	valid_0's auc: 0.891922
# [4000]	valid_0's auc: 0.894636
# [5000]	valid_0's auc: 0.896763
# [6000]	valid_0's auc: 0.898223
# [7000]	valid_0's auc: 0.899105
# [8000]	valid_0's auc: 0.899773
# [9000]	valid_0's auc: 0.900191
# [10000]	valid_0's auc: 0.900364
# [11000]	valid_0's auc: 0.900475
# [12000]	valid_0's auc: 0.900559
# [13000]	valid_0's auc: 0.900568
# [14000]	valid_0's auc: 0.900515
# [15000]	valid_0's auc: 0.90041
# Early stopping, best iteration is:
# [12790]	valid_0's auc: 0.90059
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.879026
# [2000]	valid_0's auc: 0.886716
# [3000]	valid_0's auc: 0.891422
# [4000]	valid_0's auc: 0.894375
# [5000]	valid_0's auc: 0.896493
# [6000]	valid_0's auc: 0.897943
# [7000]	valid_0's auc: 0.898882
# [8000]	valid_0's auc: 0.89949
# [9000]	valid_0's auc: 0.899798
# [10000]	valid_0's auc: 0.900022
# [11000]	valid_0's auc: 0.900063
# [12000]	valid_0's auc: 0.900151
# [13000]	valid_0's auc: 0.900164
# [14000]	valid_0's auc: 0.900136
# [15000]	valid_0's auc: 0.900169
# Early stopping, best iteration is:
# [12522]	valid_0's auc: 0.900183
#
# The 1 fold complete
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.8819
# [2000]	valid_0's auc: 0.889288
# [3000]	valid_0's auc: 0.893474
# [4000]	valid_0's auc: 0.896287
# [5000]	valid_0's auc: 0.898102
# [6000]	valid_0's auc: 0.899446
# [7000]	valid_0's auc: 0.900196
# [8000]	valid_0's auc: 0.900666
# [9000]	valid_0's auc: 0.901007
# [10000]	valid_0's auc: 0.901212
# [11000]	valid_0's auc: 0.901307
# [12000]	valid_0's auc: 0.901383
# [13000]	valid_0's auc: 0.901337
# [14000]	valid_0's auc: 0.901186
# Early stopping, best iteration is:
# [12114]	valid_0's auc: 0.901404
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.882204
# [2000]	valid_0's auc: 0.88883
# [3000]	valid_0's auc: 0.893155
# [4000]	valid_0's auc: 0.896094
# [5000]	valid_0's auc: 0.897824
# [6000]	valid_0's auc: 0.898983
# [7000]	valid_0's auc: 0.899781
# [8000]	valid_0's auc: 0.900317
# [9000]	valid_0's auc: 0.900622
# [10000]	valid_0's auc: 0.90072
# [11000]	valid_0's auc: 0.900679
# [12000]	valid_0's auc: 0.900737
# [13000]	valid_0's auc: 0.900739
# [14000]	valid_0's auc: 0.900675
# [15000]	valid_0's auc: 0.900628
# Early stopping, best iteration is:
# [12509]	valid_0's auc: 0.900799
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.88232
# [2000]	valid_0's auc: 0.889252
# [3000]	valid_0's auc: 0.89334
# [4000]	valid_0's auc: 0.895964
# [5000]	valid_0's auc: 0.897849
# [6000]	valid_0's auc: 0.899043
# [7000]	valid_0's auc: 0.899826
# [8000]	valid_0's auc: 0.900421
# [9000]	valid_0's auc: 0.900721
# [10000]	valid_0's auc: 0.900929
# [11000]	valid_0's auc: 0.900986
# [12000]	valid_0's auc: 0.901069
# [13000]	valid_0's auc: 0.901012
# [14000]	valid_0's auc: 0.900919
# Early stopping, best iteration is:
# [12179]	valid_0's auc: 0.901102
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.882066
# [2000]	valid_0's auc: 0.888816
# [3000]	valid_0's auc: 0.892818
# [4000]	valid_0's auc: 0.89575
# [5000]	valid_0's auc: 0.897746
# [6000]	valid_0's auc: 0.898948
# [7000]	valid_0's auc: 0.899787
# [8000]	valid_0's auc: 0.900252
# [9000]	valid_0's auc: 0.900524
# [10000]	valid_0's auc: 0.900711
# [11000]	valid_0's auc: 0.900774
# [12000]	valid_0's auc: 0.900776
# [13000]	valid_0's auc: 0.900787
# [14000]	valid_0's auc: 0.900808
# [15000]	valid_0's auc: 0.900701
# Early stopping, best iteration is:
# [12660]	valid_0's auc: 0.900835
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.882066
# [2000]	valid_0's auc: 0.888941
# [3000]	valid_0's auc: 0.89307
# [4000]	valid_0's auc: 0.895919
# [5000]	valid_0's auc: 0.897739
# [6000]	valid_0's auc: 0.899009
# [7000]	valid_0's auc: 0.899863
# [8000]	valid_0's auc: 0.900413
# [9000]	valid_0's auc: 0.900719
# [10000]	valid_0's auc: 0.900953
# [11000]	valid_0's auc: 0.901041
# [12000]	valid_0's auc: 0.901112
# [13000]	valid_0's auc: 0.901145
# [14000]	valid_0's auc: 0.901118
# [15000]	valid_0's auc: 0.901079
# Early stopping, best iteration is:
# [13399]	valid_0's auc: 0.901197
#
# The 2 fold complete
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.883837
# [2000]	valid_0's auc: 0.891889
# [3000]	valid_0's auc: 0.896953
# [4000]	valid_0's auc: 0.900433
# [5000]	valid_0's auc: 0.902839
# [6000]	valid_0's auc: 0.904348
# [7000]	valid_0's auc: 0.905393
# [8000]	valid_0's auc: 0.906077
# [9000]	valid_0's auc: 0.906507
# [10000]	valid_0's auc: 0.906748
# [11000]	valid_0's auc: 0.906947
# [12000]	valid_0's auc: 0.906902
# [13000]	valid_0's auc: 0.906875
# Early stopping, best iteration is:
# [11152]	valid_0's auc: 0.906974
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.884232
# [2000]	valid_0's auc: 0.891989
# [3000]	valid_0's auc: 0.896836
# [4000]	valid_0's auc: 0.900301
# [5000]	valid_0's auc: 0.902714
# [6000]	valid_0's auc: 0.9042
# [7000]	valid_0's auc: 0.905358
# [8000]	valid_0's auc: 0.905993
# [9000]	valid_0's auc: 0.90629
# [10000]	valid_0's auc: 0.906557
# [11000]	valid_0's auc: 0.906789
# [12000]	valid_0's auc: 0.906807
# [13000]	valid_0's auc: 0.90688
# [14000]	valid_0's auc: 0.906937
# [15000]	valid_0's auc: 0.906899
# [16000]	valid_0's auc: 0.906835
# Early stopping, best iteration is:
# [14295]	valid_0's auc: 0.906973
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.884115
# [2000]	valid_0's auc: 0.892007
# [3000]	valid_0's auc: 0.896932
# [4000]	valid_0's auc: 0.900317
# [5000]	valid_0's auc: 0.902582
# [6000]	valid_0's auc: 0.904048
# [7000]	valid_0's auc: 0.905132
# [8000]	valid_0's auc: 0.905819
# [9000]	valid_0's auc: 0.906211
# [10000]	valid_0's auc: 0.906409
# [11000]	valid_0's auc: 0.906623
# [12000]	valid_0's auc: 0.906686
# [13000]	valid_0's auc: 0.906669
# [14000]	valid_0's auc: 0.90668
# Early stopping, best iteration is:
# [12335]	valid_0's auc: 0.906734
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.88422
# [2000]	valid_0's auc: 0.891932
# [3000]	valid_0's auc: 0.896811
# [4000]	valid_0's auc: 0.900297
# [5000]	valid_0's auc: 0.902515
# [6000]	valid_0's auc: 0.904119
# [7000]	valid_0's auc: 0.905242
# [8000]	valid_0's auc: 0.905869
# [9000]	valid_0's auc: 0.906283
# [10000]	valid_0's auc: 0.906432
# [11000]	valid_0's auc: 0.906608
# [12000]	valid_0's auc: 0.906606
# [13000]	valid_0's auc: 0.906617
# [14000]	valid_0's auc: 0.906621
# Early stopping, best iteration is:
# [12470]	valid_0's auc: 0.906668
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.884278
# [2000]	valid_0's auc: 0.891896
# [3000]	valid_0's auc: 0.896883
# [4000]	valid_0's auc: 0.900342
# [5000]	valid_0's auc: 0.902764
# [6000]	valid_0's auc: 0.904144
# [7000]	valid_0's auc: 0.905179
# [8000]	valid_0's auc: 0.905815
# [9000]	valid_0's auc: 0.906227
# [10000]	valid_0's auc: 0.906483
# [11000]	valid_0's auc: 0.906628
# [12000]	valid_0's auc: 0.906683
# [13000]	valid_0's auc: 0.906693
# [14000]	valid_0's auc: 0.906756
# [15000]	valid_0's auc: 0.906746
# [16000]	valid_0's auc: 0.906735
# Early stopping, best iteration is:
# [13830]	valid_0's auc: 0.906761
#
# The 3 fold complete
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.877057
# [2000]	valid_0's auc: 0.885357
# [3000]	valid_0's auc: 0.890126
# [4000]	valid_0's auc: 0.893264
# [5000]	valid_0's auc: 0.895333
# [6000]	valid_0's auc: 0.897008
# [7000]	valid_0's auc: 0.898015
# [8000]	valid_0's auc: 0.898809
# [9000]	valid_0's auc: 0.899288
# [10000]	valid_0's auc: 0.899622
# [11000]	valid_0's auc: 0.899749
# [12000]	valid_0's auc: 0.899836
# [13000]	valid_0's auc: 0.899873
# [14000]	valid_0's auc: 0.899894
# [15000]	valid_0's auc: 0.899925
# [16000]	valid_0's auc: 0.899907
# [17000]	valid_0's auc: 0.899786
# [18000]	valid_0's auc: 0.899719
# Early stopping, best iteration is:
# [15569]	valid_0's auc: 0.89997
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.877282
# [2000]	valid_0's auc: 0.885529
# [3000]	valid_0's auc: 0.890417
# [4000]	valid_0's auc: 0.893649
# [5000]	valid_0's auc: 0.89577
# [6000]	valid_0's auc: 0.897269
# [7000]	valid_0's auc: 0.898161
# [8000]	valid_0's auc: 0.898929
# [9000]	valid_0's auc: 0.899435
# [10000]	valid_0's auc: 0.899769
# [11000]	valid_0's auc: 0.899904
# [12000]	valid_0's auc: 0.900031
# [13000]	valid_0's auc: 0.900075
# [14000]	valid_0's auc: 0.900087
# [15000]	valid_0's auc: 0.900078
# [16000]	valid_0's auc: 0.90014
# [17000]	valid_0's auc: 0.900186
# [18000]	valid_0's auc: 0.900084
# [19000]	valid_0's auc: 0.900026
# Early stopping, best iteration is:
# [16758]	valid_0's auc: 0.900219
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.877151
# [2000]	valid_0's auc: 0.885214
# [3000]	valid_0's auc: 0.889994
# [4000]	valid_0's auc: 0.893317
# [5000]	valid_0's auc: 0.895505
# [6000]	valid_0's auc: 0.897174
# [7000]	valid_0's auc: 0.898346
# [8000]	valid_0's auc: 0.898967
# [9000]	valid_0's auc: 0.899479
# [10000]	valid_0's auc: 0.899806
# [11000]	valid_0's auc: 0.900074
# [12000]	valid_0's auc: 0.900256
# [13000]	valid_0's auc: 0.900301
# [14000]	valid_0's auc: 0.900355
# [15000]	valid_0's auc: 0.900358
# [16000]	valid_0's auc: 0.900274
# [17000]	valid_0's auc: 0.900229
# Early stopping, best iteration is:
# [14668]	valid_0's auc: 0.900414
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.876972
# [2000]	valid_0's auc: 0.885474
# [3000]	valid_0's auc: 0.890362
# [4000]	valid_0's auc: 0.893625
# [5000]	valid_0's auc: 0.895752
# [6000]	valid_0's auc: 0.897281
# [7000]	valid_0's auc: 0.898376
# [8000]	valid_0's auc: 0.899199
# [9000]	valid_0's auc: 0.899743
# [10000]	valid_0's auc: 0.900046
# [11000]	valid_0's auc: 0.900257
# [12000]	valid_0's auc: 0.900331
# [13000]	valid_0's auc: 0.900344
# [14000]	valid_0's auc: 0.900347
# [15000]	valid_0's auc: 0.90033
# [16000]	valid_0's auc: 0.900265
# Early stopping, best iteration is:
# [14395]	valid_0's auc: 0.900395
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.877664
# [2000]	valid_0's auc: 0.885754
# [3000]	valid_0's auc: 0.890589
# [4000]	valid_0's auc: 0.893643
# [5000]	valid_0's auc: 0.895691
# [6000]	valid_0's auc: 0.897288
# [7000]	valid_0's auc: 0.898319
# [8000]	valid_0's auc: 0.899067
# [9000]	valid_0's auc: 0.899525
# [10000]	valid_0's auc: 0.899807
# [11000]	valid_0's auc: 0.899925
# [12000]	valid_0's auc: 0.900022
# [13000]	valid_0's auc: 0.900052
# [14000]	valid_0's auc: 0.900045
# [15000]	valid_0's auc: 0.900036
# [16000]	valid_0's auc: 0.899994
# Early stopping, best iteration is:
# [14314]	valid_0's auc: 0.900106
#
# The 4 fold complete
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.874485
# [2000]	valid_0's auc: 0.882625
# [3000]	valid_0's auc: 0.887544
# [4000]	valid_0's auc: 0.89095
# [5000]	valid_0's auc: 0.893299
# [6000]	valid_0's auc: 0.894848
# [7000]	valid_0's auc: 0.895804
# [8000]	valid_0's auc: 0.89651
# [9000]	valid_0's auc: 0.896921
# [10000]	valid_0's auc: 0.897118
# [11000]	valid_0's auc: 0.897191
# [12000]	valid_0's auc: 0.897286
# [13000]	valid_0's auc: 0.897292
# [14000]	valid_0's auc: 0.897189
# [15000]	valid_0's auc: 0.897112
# Early stopping, best iteration is:
# [12741]	valid_0's auc: 0.897313
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.874805
# [2000]	valid_0's auc: 0.883
# [3000]	valid_0's auc: 0.887884
# [4000]	valid_0's auc: 0.891394
# [5000]	valid_0's auc: 0.893776
# [6000]	valid_0's auc: 0.895249
# [7000]	valid_0's auc: 0.896299
# [8000]	valid_0's auc: 0.896934
# [9000]	valid_0's auc: 0.897363
# [10000]	valid_0's auc: 0.897585
# [11000]	valid_0's auc: 0.897796
# [12000]	valid_0's auc: 0.897874
# [13000]	valid_0's auc: 0.897914
# [14000]	valid_0's auc: 0.897969
# [15000]	valid_0's auc: 0.897907
# [16000]	valid_0's auc: 0.89783
# Early stopping, best iteration is:
# [13796]	valid_0's auc: 0.898023
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.874633
# [2000]	valid_0's auc: 0.883203
# [3000]	valid_0's auc: 0.888061
# [4000]	valid_0's auc: 0.891453
# [5000]	valid_0's auc: 0.893839
# [6000]	valid_0's auc: 0.895382
# [7000]	valid_0's auc: 0.89629
# [8000]	valid_0's auc: 0.89691
# [9000]	valid_0's auc: 0.897252
# [10000]	valid_0's auc: 0.89753
# [11000]	valid_0's auc: 0.897754
# [12000]	valid_0's auc: 0.897827
# [13000]	valid_0's auc: 0.897834
# [14000]	valid_0's auc: 0.897714
# Early stopping, best iteration is:
# [11890]	valid_0's auc: 0.89786
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.87437
# [2000]	valid_0's auc: 0.882536
# [3000]	valid_0's auc: 0.887593
# [4000]	valid_0's auc: 0.890978
# [5000]	valid_0's auc: 0.893443
# [6000]	valid_0's auc: 0.894898
# [7000]	valid_0's auc: 0.895823
# [8000]	valid_0's auc: 0.896616
# [9000]	valid_0's auc: 0.897016
# [10000]	valid_0's auc: 0.897334
# [11000]	valid_0's auc: 0.897453
# [12000]	valid_0's auc: 0.897477
# [13000]	valid_0's auc: 0.897473
# [14000]	valid_0's auc: 0.897488
# [15000]	valid_0's auc: 0.897376
# Early stopping, best iteration is:
# [12589]	valid_0's auc: 0.897509
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.874312
# [2000]	valid_0's auc: 0.882495
# [3000]	valid_0's auc: 0.887544
# [4000]	valid_0's auc: 0.890893
# [5000]	valid_0's auc: 0.893319
# [6000]	valid_0's auc: 0.894896
# [7000]	valid_0's auc: 0.895931
# [8000]	valid_0's auc: 0.896658
# [9000]	valid_0's auc: 0.897209
# [10000]	valid_0's auc: 0.897408
# [11000]	valid_0's auc: 0.897651
# [12000]	valid_0's auc: 0.897789
# [13000]	valid_0's auc: 0.897819
# [14000]	valid_0's auc: 0.897783
# [15000]	valid_0's auc: 0.897744
# Early stopping, best iteration is:
# [13124]	valid_0's auc: 0.897832
#
# The 5 fold complete

# %%
result = pd.DataFrame({"ID_code":test_rd["ID_code"].values})

result['target'] = predictions

result.to_csv("submission.csv", index=False)
