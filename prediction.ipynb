# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold


train_rd = pd.read_csv('train.csv')
test_rd = pd.read_csv('test.csv')

group_0 = train_rd.loc[train_rd['target']==0]
group_1 = train_rd.loc[train_rd['target']==1]

# %%
features = [c for c in train_rd.columns if c not in ['ID_code', 'target']]
target = train_rd['target']

param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.333,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.005,
    'max_depth': -1,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 10,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': 1
}

# %%
folds = StratifiedKFold(n_splits=15, shuffle=False,random_state=2319)
predictions = np.zeros(len(test_rd))

predictions_list = []

for fold_count, (train_idx, valid_idx) in enumerate(folds.split(train_rd.values, target.values)):
    
    train_data = lgb.Dataset(train_rd.iloc[train_idx][features],label=target.iloc[train_idx])
    valid_data = lgb.Dataset(train_rd.iloc[valid_idx][features],label=target.iloc[valid_idx])
    
    clf = lgb.train(param, train_data, 50000, valid_sets = valid_data, verbose_eval=1000, early_stopping_rounds = 2500)
    
    predictions = clf.predict(test_rd[features], num_iteration=clf.best_iteration)
    
    print('\n============== Prediction iteration END ==============\n')
    
    predictions_list.append(predictions)
# Out:
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.872425
# [2000]	valid_0's auc: 0.879734
# [3000]	valid_0's auc: 0.884733
# [4000]	valid_0's auc: 0.888339
# [5000]	valid_0's auc: 0.891376
# [6000]	valid_0's auc: 0.893611
# [7000]	valid_0's auc: 0.89528
# [8000]	valid_0's auc: 0.896994
# [9000]	valid_0's auc: 0.898336
# [10000]	valid_0's auc: 0.899356
# [11000]	valid_0's auc: 0.900234
# [12000]	valid_0's auc: 0.900918
# [13000]	valid_0's auc: 0.901496
# [14000]	valid_0's auc: 0.901705
# [15000]	valid_0's auc: 0.902046
# [16000]	valid_0's auc: 0.902218
# [17000]	valid_0's auc: 0.902409
# [18000]	valid_0's auc: 0.902322
# [19000]	valid_0's auc: 0.902558
# [20000]	valid_0's auc: 0.902563
# [21000]	valid_0's auc: 0.902639
# [22000]	valid_0's auc: 0.902643
# [23000]	valid_0's auc: 0.9027
# [24000]	valid_0's auc: 0.902677
# [25000]	valid_0's auc: 0.902671
# [26000]	valid_0's auc: 0.902674
# Early stopping, best iteration is:
# [23738]	valid_0's auc: 0.902736
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.869367
# [2000]	valid_0's auc: 0.876277
# [3000]	valid_0's auc: 0.880231
# [4000]	valid_0's auc: 0.883216
# [5000]	valid_0's auc: 0.885409
# [6000]	valid_0's auc: 0.887225
# [7000]	valid_0's auc: 0.88882
# [8000]	valid_0's auc: 0.890119
# [9000]	valid_0's auc: 0.891148
# [10000]	valid_0's auc: 0.89215
# [11000]	valid_0's auc: 0.892637
# [12000]	valid_0's auc: 0.893166
# [13000]	valid_0's auc: 0.893441
# [14000]	valid_0's auc: 0.893743
# [15000]	valid_0's auc: 0.893831
# [16000]	valid_0's auc: 0.894036
# [17000]	valid_0's auc: 0.894174
# [18000]	valid_0's auc: 0.8944
# [19000]	valid_0's auc: 0.894606
# [20000]	valid_0's auc: 0.894708
# [21000]	valid_0's auc: 0.894777
# [22000]	valid_0's auc: 0.894745
# [23000]	valid_0's auc: 0.89482
# [24000]	valid_0's auc: 0.894743
# [25000]	valid_0's auc: 0.894749
# Early stopping, best iteration is:
# [22911]	valid_0's auc: 0.894856
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.874951
# [2000]	valid_0's auc: 0.884161
# [3000]	valid_0's auc: 0.88881
# [4000]	valid_0's auc: 0.891872
# [5000]	valid_0's auc: 0.894449
# [6000]	valid_0's auc: 0.896462
# [7000]	valid_0's auc: 0.898182
# [8000]	valid_0's auc: 0.899611
# [9000]	valid_0's auc: 0.900658
# [10000]	valid_0's auc: 0.901331
# [11000]	valid_0's auc: 0.902022
# [12000]	valid_0's auc: 0.90268
# [13000]	valid_0's auc: 0.903118
# [14000]	valid_0's auc: 0.903424
# [15000]	valid_0's auc: 0.903737
# [16000]	valid_0's auc: 0.90388
# [17000]	valid_0's auc: 0.903811
# [18000]	valid_0's auc: 0.903809
# [19000]	valid_0's auc: 0.903866
# [20000]	valid_0's auc: 0.90382
# [21000]	valid_0's auc: 0.903658
# Early stopping, best iteration is:
# [18834]	valid_0's auc: 0.903904
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.861221
# [2000]	valid_0's auc: 0.869494
# [3000]	valid_0's auc: 0.874267
# [4000]	valid_0's auc: 0.87743
# [5000]	valid_0's auc: 0.87958
# [6000]	valid_0's auc: 0.88167
# [7000]	valid_0's auc: 0.883499
# [8000]	valid_0's auc: 0.885162
# [9000]	valid_0's auc: 0.886234
# [10000]	valid_0's auc: 0.887233
# [11000]	valid_0's auc: 0.887829
# [12000]	valid_0's auc: 0.888237
# [13000]	valid_0's auc: 0.888645
# [14000]	valid_0's auc: 0.888962
# [15000]	valid_0's auc: 0.889324
# [16000]	valid_0's auc: 0.889625
# [17000]	valid_0's auc: 0.889787
# [18000]	valid_0's auc: 0.889903
# [19000]	valid_0's auc: 0.889959
# [20000]	valid_0's auc: 0.889978
# [21000]	valid_0's auc: 0.890011
# [22000]	valid_0's auc: 0.890027
# [23000]	valid_0's auc: 0.890065
# [24000]	valid_0's auc: 0.889974
# [25000]	valid_0's auc: 0.889965
# Early stopping, best iteration is:
# [22528]	valid_0's auc: 0.890091
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.878197
# [2000]	valid_0's auc: 0.887952
# [3000]	valid_0's auc: 0.893483
# [4000]	valid_0's auc: 0.897612
# [5000]	valid_0's auc: 0.9007
# [6000]	valid_0's auc: 0.90298
# [7000]	valid_0's auc: 0.904526
# [8000]	valid_0's auc: 0.90581
# [9000]	valid_0's auc: 0.906683
# [10000]	valid_0's auc: 0.907407
# [11000]	valid_0's auc: 0.908053
# [12000]	valid_0's auc: 0.908448
# [13000]	valid_0's auc: 0.908665
# [14000]	valid_0's auc: 0.908933
# [15000]	valid_0's auc: 0.909127
# [16000]	valid_0's auc: 0.909162
# [17000]	valid_0's auc: 0.90912
# [18000]	valid_0's auc: 0.909206
# [19000]	valid_0's auc: 0.90927
# [20000]	valid_0's auc: 0.909237
# [21000]	valid_0's auc: 0.909208
# [22000]	valid_0's auc: 0.909121
# Early stopping, best iteration is:
# [20417]	valid_0's auc: 0.909283
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.865344
# [2000]	valid_0's auc: 0.874738
# [3000]	valid_0's auc: 0.879064
# [4000]	valid_0's auc: 0.882576
# [5000]	valid_0's auc: 0.88477
# [6000]	valid_0's auc: 0.886613
# [7000]	valid_0's auc: 0.888554
# [8000]	valid_0's auc: 0.889741
# [9000]	valid_0's auc: 0.890769
# [10000]	valid_0's auc: 0.891601
# [11000]	valid_0's auc: 0.892071
# [12000]	valid_0's auc: 0.892541
# [13000]	valid_0's auc: 0.892919
# [14000]	valid_0's auc: 0.893161
# [15000]	valid_0's auc: 0.893312
# [16000]	valid_0's auc: 0.893378
# [17000]	valid_0's auc: 0.893373
# [18000]	valid_0's auc: 0.893268
# [19000]	valid_0's auc: 0.893266
# Early stopping, best iteration is:
# [17400]	valid_0's auc: 0.89343
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.871742
# [2000]	valid_0's auc: 0.879813
# [3000]	valid_0's auc: 0.885452
# [4000]	valid_0's auc: 0.889097
# [5000]	valid_0's auc: 0.891833
# [6000]	valid_0's auc: 0.89434
# [7000]	valid_0's auc: 0.896203
# [8000]	valid_0's auc: 0.897626
# [9000]	valid_0's auc: 0.898347
# [10000]	valid_0's auc: 0.899009
# [11000]	valid_0's auc: 0.899346
# [12000]	valid_0's auc: 0.899722
# [13000]	valid_0's auc: 0.900028
# [14000]	valid_0's auc: 0.900196
# [15000]	valid_0's auc: 0.900424
# [16000]	valid_0's auc: 0.900561
# [17000]	valid_0's auc: 0.900632
# [18000]	valid_0's auc: 0.900612
# [19000]	valid_0's auc: 0.900711
# [20000]	valid_0's auc: 0.900655
# [21000]	valid_0's auc: 0.900552
# Early stopping, best iteration is:
# [18742]	valid_0's auc: 0.900734
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.873666
# [2000]	valid_0's auc: 0.882006
# [3000]	valid_0's auc: 0.886612
# [4000]	valid_0's auc: 0.88991
# [5000]	valid_0's auc: 0.892662
# [6000]	valid_0's auc: 0.894668
# [7000]	valid_0's auc: 0.89616
# [8000]	valid_0's auc: 0.897435
# [9000]	valid_0's auc: 0.898634
# [10000]	valid_0's auc: 0.899313
# [11000]	valid_0's auc: 0.899874
# [12000]	valid_0's auc: 0.900306
# [13000]	valid_0's auc: 0.900607
# [14000]	valid_0's auc: 0.900831
# [15000]	valid_0's auc: 0.9012
# [16000]	valid_0's auc: 0.901359
# [17000]	valid_0's auc: 0.901494
# [18000]	valid_0's auc: 0.901583
# [19000]	valid_0's auc: 0.90162
# [20000]	valid_0's auc: 0.901683
# [21000]	valid_0's auc: 0.901734
# [22000]	valid_0's auc: 0.901736
# [23000]	valid_0's auc: 0.901627
# Early stopping, best iteration is:
# [20695]	valid_0's auc: 0.90179
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.87868
# [2000]	valid_0's auc: 0.886472
# [3000]	valid_0's auc: 0.891554
# [4000]	valid_0's auc: 0.894814
# [5000]	valid_0's auc: 0.897114
# [6000]	valid_0's auc: 0.898889
# [7000]	valid_0's auc: 0.900327
# [8000]	valid_0's auc: 0.901495
# [9000]	valid_0's auc: 0.902379
# [10000]	valid_0's auc: 0.903145
# [11000]	valid_0's auc: 0.903617
# [12000]	valid_0's auc: 0.90393
# [13000]	valid_0's auc: 0.904122
# [14000]	valid_0's auc: 0.90434
# [15000]	valid_0's auc: 0.90454
# [16000]	valid_0's auc: 0.904655
# [17000]	valid_0's auc: 0.904601
# [18000]	valid_0's auc: 0.904637
# [19000]	valid_0's auc: 0.904689
# [20000]	valid_0's auc: 0.904722
# [21000]	valid_0's auc: 0.904674
# [22000]	valid_0's auc: 0.904659
# Early stopping, best iteration is:
# [20348]	valid_0's auc: 0.90476
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.876628
# [2000]	valid_0's auc: 0.884387
# [3000]	valid_0's auc: 0.888542
# [4000]	valid_0's auc: 0.892345
# [5000]	valid_0's auc: 0.894751
# [6000]	valid_0's auc: 0.896898
# [7000]	valid_0's auc: 0.898186
# [8000]	valid_0's auc: 0.899305
# [9000]	valid_0's auc: 0.900192
# [10000]	valid_0's auc: 0.900852
# [11000]	valid_0's auc: 0.901323
# [12000]	valid_0's auc: 0.901595
# [13000]	valid_0's auc: 0.901926
# [14000]	valid_0's auc: 0.90205
# [15000]	valid_0's auc: 0.902175
# [16000]	valid_0's auc: 0.902289
# [17000]	valid_0's auc: 0.902469
# [18000]	valid_0's auc: 0.902486
# [19000]	valid_0's auc: 0.902458
# [20000]	valid_0's auc: 0.902393
# Early stopping, best iteration is:
# [17832]	valid_0's auc: 0.902588
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.86737
# [2000]	valid_0's auc: 0.875576
# [3000]	valid_0's auc: 0.88106
# [4000]	valid_0's auc: 0.884781
# [5000]	valid_0's auc: 0.88816
# [6000]	valid_0's auc: 0.890417
# [7000]	valid_0's auc: 0.892104
# [8000]	valid_0's auc: 0.893773
# [9000]	valid_0's auc: 0.894779
# [10000]	valid_0's auc: 0.89575
# [11000]	valid_0's auc: 0.896385
# [12000]	valid_0's auc: 0.896813
# [13000]	valid_0's auc: 0.897071
# [14000]	valid_0's auc: 0.897297
# [15000]	valid_0's auc: 0.897486
# [16000]	valid_0's auc: 0.897666
# [17000]	valid_0's auc: 0.897855
# [18000]	valid_0's auc: 0.897974
# [19000]	valid_0's auc: 0.898037
# [20000]	valid_0's auc: 0.897988
# [21000]	valid_0's auc: 0.897951
# [22000]	valid_0's auc: 0.898059
# [23000]	valid_0's auc: 0.897999
# [24000]	valid_0's auc: 0.898012
# Early stopping, best iteration is:
# [22473]	valid_0's auc: 0.898095
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.873993
# [2000]	valid_0's auc: 0.881388
# [3000]	valid_0's auc: 0.887111
# [4000]	valid_0's auc: 0.890966
# [5000]	valid_0's auc: 0.893886
# [6000]	valid_0's auc: 0.895984
# [7000]	valid_0's auc: 0.897462
# [8000]	valid_0's auc: 0.898741
# [9000]	valid_0's auc: 0.899792
# [10000]	valid_0's auc: 0.900596
# [11000]	valid_0's auc: 0.90121
# [12000]	valid_0's auc: 0.901775
# [13000]	valid_0's auc: 0.902087
# [14000]	valid_0's auc: 0.902383
# [15000]	valid_0's auc: 0.902589
# [16000]	valid_0's auc: 0.902673
# [17000]	valid_0's auc: 0.902807
# [18000]	valid_0's auc: 0.902864
# [19000]	valid_0's auc: 0.902936
# [20000]	valid_0's auc: 0.902923
# [21000]	valid_0's auc: 0.902877
# Early stopping, best iteration is:
# [19178]	valid_0's auc: 0.902983
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.878726
# [2000]	valid_0's auc: 0.88595
# [3000]	valid_0's auc: 0.89115
# [4000]	valid_0's auc: 0.894722
# [5000]	valid_0's auc: 0.897318
# [6000]	valid_0's auc: 0.899133
# [7000]	valid_0's auc: 0.900602
# [8000]	valid_0's auc: 0.901842
# [9000]	valid_0's auc: 0.902635
# [10000]	valid_0's auc: 0.903119
# [11000]	valid_0's auc: 0.903622
# [12000]	valid_0's auc: 0.903859
# [13000]	valid_0's auc: 0.904066
# [14000]	valid_0's auc: 0.904088
# [15000]	valid_0's auc: 0.904176
# [16000]	valid_0's auc: 0.904184
# [17000]	valid_0's auc: 0.904283
# [18000]	valid_0's auc: 0.904351
# [19000]	valid_0's auc: 0.904281
# [20000]	valid_0's auc: 0.904252
# Early stopping, best iteration is:
# [17891]	valid_0's auc: 0.904375
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.882606
# [2000]	valid_0's auc: 0.88945
# [3000]	valid_0's auc: 0.895032
# [4000]	valid_0's auc: 0.898622
# [5000]	valid_0's auc: 0.901425
# [6000]	valid_0's auc: 0.903688
# [7000]	valid_0's auc: 0.905378
# [8000]	valid_0's auc: 0.907007
# [9000]	valid_0's auc: 0.908064
# [10000]	valid_0's auc: 0.908873
# [11000]	valid_0's auc: 0.909538
# [12000]	valid_0's auc: 0.909808
# [13000]	valid_0's auc: 0.910336
# [14000]	valid_0's auc: 0.910614
# [15000]	valid_0's auc: 0.910966
# [16000]	valid_0's auc: 0.911099
# [17000]	valid_0's auc: 0.91131
# [18000]	valid_0's auc: 0.911519
# [19000]	valid_0's auc: 0.911525
# [20000]	valid_0's auc: 0.911713
# [21000]	valid_0's auc: 0.911628
# [22000]	valid_0's auc: 0.911579
# Early stopping, best iteration is:
# [20102]	valid_0's auc: 0.911729
#
# ============== Prediction iteration END ==============
#
# Training until validation scores don't improve for 2500 rounds.
# [1000]	valid_0's auc: 0.873311
# [2000]	valid_0's auc: 0.879013
# [3000]	valid_0's auc: 0.883475
# [4000]	valid_0's auc: 0.886251
# [5000]	valid_0's auc: 0.888383
# [6000]	valid_0's auc: 0.890125
# [7000]	valid_0's auc: 0.891738
# [8000]	valid_0's auc: 0.892847
# [9000]	valid_0's auc: 0.89383
# [10000]	valid_0's auc: 0.894511
# [11000]	valid_0's auc: 0.895005
# [12000]	valid_0's auc: 0.895417
# [13000]	valid_0's auc: 0.895819
# [14000]	valid_0's auc: 0.896125
# [15000]	valid_0's auc: 0.896171
# [16000]	valid_0's auc: 0.896294
# [17000]	valid_0's auc: 0.896308
# [18000]	valid_0's auc: 0.896413
# [19000]	valid_0's auc: 0.896386
# [20000]	valid_0's auc: 0.896405
# [21000]	valid_0's auc: 0.89646
# [22000]	valid_0's auc: 0.896508
# [23000]	valid_0's auc: 0.896495
# [24000]	valid_0's auc: 0.896463
# [25000]	valid_0's auc: 0.896401
# Early stopping, best iteration is:
# [23094]	valid_0's auc: 0.89653
#
# ============== Prediction iteration END ==============

# %%
result = pd.DataFrame({"ID_code":test_rd["ID_code"].values})

result['target'] = predictions_list[13]

result.to_csv("submission.csv", index=False)
